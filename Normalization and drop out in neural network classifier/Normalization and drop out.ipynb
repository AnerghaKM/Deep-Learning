# %% [markdown]
# **Normalization and drop out in neural network classifier**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the model with Batch Normalization and Dropout
model = keras.Sequential([
    layers.Dense(64, input_dim=4, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(3, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 4s 70ms/step - loss: 2.0573 - accuracy: 0.3148 - val_loss: 1.0244 - val_accuracy: 0.9167
# Epoch 2/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.4572 - accuracy: 0.3981 - val_loss: 0.9679 - val_accuracy: 0.6667
# Epoch 3/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.3530 - accuracy: 0.4722 - val_loss: 0.9165 - val_accuracy: 0.5833
# Epoch 4/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0117 - accuracy: 0.5648 - val_loss: 0.8742 - val_accuracy: 0.5833
# Epoch 5/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7447 - accuracy: 0.6759 - val_loss: 0.8377 - val_accuracy: 0.5833
# Epoch 6/50
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7205 - accuracy: 0.7407 - val_loss: 0.8067 - val_accuracy: 0.5833
# Epoch 7/50
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5411 - accuracy: 0.7685 - val_loss: 0.7790 - val_accuracy: 0.5833
# Epoch 8/50
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5125 - accuracy: 0.7685 - val_loss: 0.7538 - val_accuracy: 0.5833
# Epoch 9/50
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6189 - accuracy: 0.6944 - val_loss: 0.7315 - val_accuracy: 0.5833
# Epoch 10/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.5924 - accuracy: 0.7870 - val_loss: 0.7101 - val_accuracy: 0.5833
# Epoch 11/50
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3841 - accuracy: 0.8519 - val_loss: 0.6894 - val_accuracy: 0.5833
# Epoch 12/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.4097 - accuracy: 0.8333 - val_loss: 0.6712 - val_accuracy: 0.6667
# Epoch 13/50
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3796 - accuracy: 0.8333 - val_loss: 0.6512 - val_accuracy: 0.6667
# Epoch 14/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4734 - accuracy: 0.8333 - val_loss: 0.6342 - val_accuracy: 0.8333
# Epoch 15/50
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2276 - accuracy: 0.9074 - val_loss: 0.6166 - val_accuracy: 0.8333
# Epoch 16/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4449 - accuracy: 0.8056 - val_loss: 0.5985 - val_accuracy: 0.9167
# Epoch 17/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2783 - accuracy: 0.8796 - val_loss: 0.5789 - val_accuracy: 0.9167
# Epoch 18/50
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3234 - accuracy: 0.8889 - val_loss: 0.5616 - val_accuracy: 0.9167
# Epoch 19/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3489 - accuracy: 0.8426 - val_loss: 0.5454 - val_accuracy: 0.9167
# Epoch 20/50
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3082 - accuracy: 0.8611 - val_loss: 0.5292 - val_accuracy: 0.9167
# Epoch 21/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2435 - accuracy: 0.8981 - val_loss: 0.5127 - val_accuracy: 0.9167
# Epoch 22/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2875 - accuracy: 0.8889 - val_loss: 0.4966 - val_accuracy: 0.9167
# Epoch 23/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2076 - accuracy: 0.9259 - val_loss: 0.4815 - val_accuracy: 0.9167
# Epoch 24/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2506 - accuracy: 0.9074 - val_loss: 0.4678 - val_accuracy: 0.9167
# Epoch 25/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2335 - accuracy: 0.9259 - val_loss: 0.4559 - val_accuracy: 0.9167
# Epoch 26/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2580 - accuracy: 0.8796 - val_loss: 0.4444 - val_accuracy: 0.9167
# Epoch 27/50
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2670 - accuracy: 0.8796 - val_loss: 0.4321 - val_accuracy: 0.9167
# Epoch 28/50
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2281 - accuracy: 0.8981 - val_loss: 0.4199 - val_accuracy: 1.0000
# Epoch 29/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1450 - accuracy: 0.9259 - val_loss: 0.4075 - val_accuracy: 1.0000
# Epoch 30/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2768 - accuracy: 0.8796 - val_loss: 0.3949 - val_accuracy: 1.0000
# Epoch 31/50
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1888 - accuracy: 0.9074 - val_loss: 0.3828 - val_accuracy: 0.9167
# Epoch 32/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2037 - accuracy: 0.8981 - val_loss: 0.3725 - val_accuracy: 0.9167
# Epoch 33/50
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1881 - accuracy: 0.9259 - val_loss: 0.3624 - val_accuracy: 0.9167
# Epoch 34/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1459 - accuracy: 0.9630 - val_loss: 0.3537 - val_accuracy: 0.9167
# Epoch 35/50
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1561 - accuracy: 0.9259 - val_loss: 0.3451 - val_accuracy: 0.9167
# Epoch 36/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2543 - accuracy: 0.8981 - val_loss: 0.3366 - val_accuracy: 0.9167
# Epoch 37/50
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2828 - accuracy: 0.8889 - val_loss: 0.3283 - val_accuracy: 0.9167
# Epoch 38/50
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2028 - accuracy: 0.8981 - val_loss: 0.3212 - val_accuracy: 0.9167
# Epoch 39/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2618 - accuracy: 0.9259 - val_loss: 0.3136 - val_accuracy: 0.9167
# Epoch 40/50
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1675 - accuracy: 0.9167 - val_loss: 0.3069 - val_accuracy: 0.9167
# Epoch 41/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1576 - accuracy: 0.9444 - val_loss: 0.3017 - val_accuracy: 0.9167
# Epoch 42/50
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1694 - accuracy: 0.9259 - val_loss: 0.2941 - val_accuracy: 0.9167
# Epoch 43/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2221 - accuracy: 0.9259 - val_loss: 0.2856 - val_accuracy: 0.9167
# Epoch 44/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1236 - accuracy: 0.9537 - val_loss: 0.2780 - val_accuracy: 0.9167
# Epoch 45/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1924 - accuracy: 0.9444 - val_loss: 0.2715 - val_accuracy: 0.9167
# Epoch 46/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2862 - accuracy: 0.8889 - val_loss: 0.2669 - val_accuracy: 0.9167
# Epoch 47/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1752 - accuracy: 0.9352 - val_loss: 0.2612 - val_accuracy: 0.9167
# Epoch 48/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2128 - accuracy: 0.9167 - val_loss: 0.2530 - val_accuracy: 0.9167
# Epoch 49/50
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2248 - accuracy: 0.9352 - val_loss: 0.2451 - val_accuracy: 0.9167
# Epoch 50/50
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0876 - accuracy: 0.9722 - val_loss: 0.2372 - val_accuracy: 0.9167
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1387 - accuracy: 0.9667
# Test accuracy: 0.9666666388511658
